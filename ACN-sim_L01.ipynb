# %% [markdown]
# # [ACN-Sim Tutorial: Lesson 1][acn-sim_1]
#
# ## Running an Experiment
#
# ### by Zachary Lee
# ### Last updated: 03/19/2019
#
# In this first lesson we will learn how to setup and run a simulation using a built-in scheduling algorithm. After running the simulation we will learn how to use the analysis subpackage to analyze the results of the simulation.
#
# [acn-sim_1]: https://acnportal.readthedocs.io/en/latest/tutorials/acnsim/lesson1.html#ACN-Sim-Tutorial:-Lesson-1

# %%
import pytz
import os

from datetime import datetime

import matplotlib.pyplot as plt

from acnportal import acnsim
from acnportal import algorithms

# %% [markdown]
# ## [Experiment Parameters][acn-sim_1-exp_par]
#
# Next we need to define some parameters of the experiment. We define these at the begining of the file so they can be used consistently when setting up the simulation.
#
# [acn-sim_1-exp_par]: https://acnportal.readthedocs.io/en/latest/tutorials/acnsim/lesson1.html#Experiment-Parameters

# %%
# find the Olson TimeZone Identifier for NL
print(' '.join(pytz.country_timezones('NL')))
# Out:
# Europe/Amsterdam

# %%
# Timezone of the ACN we are using.
timezone = pytz.timezone('Europe/Amsterdam')

# Start and End times are used when collecting data.
start = timezone.localize(datetime(2018, 9, 5))
end = timezone.localize(datetime(2018, 9, 6))

# How long each time discrete time interval in the simulation should be.
period = 5  # minutes

# Voltage of the network.
voltage = 220  # volts

# Default maximum charging rate for each EV battery.
default_battery_power = 32 * voltage / 1000 # kW

# Identifier of the site where data will be gathered.
site = 'caltech'

# %% [markdown]
# ## [Network][acn-sim_1-network]
#
# An important part of any simulation is the ChargingNetwork on which it runs. The ChargingNetwork is a description of the physical system and contains both the set of EVSEs which make up the network as well as a constraint_matrix which represents the electrical infrastructure of the network. You can manually configure this network using the register_evse() and add_constraint() methods in ChargingNetwork or you can use a predefined network available in the sites module. In this case we use the predefined CaltechACN network.
#
# [acn-sim_1-network]: https://acnportal.readthedocs.io/en/latest/tutorials/acnsim/lesson1.html#Network

# %%
# For this experiment we use the predefined CaltechACN network.
cn = acnsim.sites.caltech_acn(basic_evse=True, voltage=voltage)

# %% [markdown]
# ## [Events][acn-sim_1-events]
#
# Events are what drive action in the simulator. Events are stored in an EventQueue. This queue can be built manually by creating an Event object and using the add_event() or add_events() methods, or can be generated automatically.
#
# In this case we will use acndata_events.generate_events() which is part of the events subpackage. acnevents provides utilities for generating events from the Caltech Charging Dataset. These events are based on real behavior of users charging actual EVs, so it is extremely valuable for running realistic simulations. In order to access the API we need a token. For now we can use the demo token, but it is highly recomended that you register for your own free token at ev.caltech.edu.
#
# [acn-sim_1-events]: https://acnportal.readthedocs.io/en/latest/tutorials/acnsim/lesson1.html#Events

# %%
API_KEY = os.getenv('API_KEY')
events = acnsim.acndata_events.generate_events(API_KEY, site, start, end, period, voltage, default_battery_power)

# %% [markdown]
# ## [Scheduling Algorithm][acn-sim_1-sched_alg]
#
# The primary purpose of acnportal is to evaluate scheduling algorithms for large-scale EV charging. We will discuss how develop your own custom algorithm in Lesson 2, for now we will use one of the builtin scheduling algorithms, UncontrolledCharging.
#
# [acn-sim_1-sched_alg]: https://acnportal.readthedocs.io/en/latest/tutorials/acnsim/lesson1.html#Scheduling-Algorithm

# %%
sch = algorithms.UncontrolledCharging()

# %% [markdown]
# ## [Simulator][acn-sim_1-simulator]
#
# We next need to set up our simulation enviroment using the parts we have already defined. The Simulator constructor takes in a ChargingNetwork, Algorithm, and EventQueue. We also provide the start time of the simulation which all internal timestamps will be measured relative to. Finally we pass in the length of each period as well as a parameter called max_recomp. max_recomp controls how often the scheduling algorithm is called when no events occur. Here we have set max_recomp to 1, meaning the scheduling algorithm will be called every time step. If we had set it to 5, up to 5 time steps could occur before the scheduling algorithm was called. Note that the scheduling algorithm is always called when an event occurs. In this case, UncontrolledCharging only provides one charging rate, so it must be used with a max_recomp of 1.
#
# [acn-sim_1-simulator]: https://acnportal.readthedocs.io/en/latest/tutorials/acnsim/lesson1.html#Simulator

# %%
sim = acnsim.Simulator(cn, sch, events, start, period=period, verbose=False)

# %% [markdown]
# To execute the simulation we simply call the ```run()``` function.

# %%
sim.run()
# Out:
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 192. Max violation is 15.999989999999997 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 193. Max violation is 15.999989999999997 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 194. Max violation is 15.999989999999997 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 195. Max violation is 15.999989999999997 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 196. Max violation is 15.999989999999997 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 197. Max violation is 47.99999 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 198. Max violation is 47.99999 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 199. Max violation is 47.99999 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 200. Max violation is 15.999989999999997 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 201. Max violation is 47.99999 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 202. Max violation is 47.99999 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 203. Max violation is 79.99999 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 204. Max violation is 79.99999 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 205. Max violation is 79.99999 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 206. Max violation is 79.99999 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 207. Max violation is 79.99999 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 208. Max violation is 79.99999 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 209. Max violation is 79.99999 A on AV Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 210. Max violation is 79.99999 A on CC Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 211. Max violation is 79.99999 A on CC Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 212. Max violation is 79.99999 A on CC Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 213. Max violation is 111.99999 A on CC Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 214. Max violation is 112.06009587279908 A on Secondary A at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 215. Max violation is 83.18930259135925 A on Secondary A at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 216. Max violation is 112.06009587279908 A on Secondary A at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 217. Max violation is 110.11980759427178 A on Secondary A at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 218. Max violation is 138.51257366605245 A on Secondary A at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 219. Max violation is 138.51257366605245 A on Secondary A at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 220. Max violation is 27.89153099572701 A on Secondary A at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 221. Max violation is 15.999989999999997 A on CC Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 222. Max violation is 15.999989999999997 A on CC Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 223. Max violation is 15.999989999999997 A on CC Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 224. Max violation is 15.999989999999997 A on CC Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 225. Max violation is 15.999989999999997 A on CC Pod at time index 0.
#   warnings.warn(
# /home/floris/miniconda3/envs/acn_py39/lib/python3.9/site-packages/acnportal/acnsim/simulator.py:277: UserWarning: Invalid schedule provided at iteration 270. Max violation is 15.999989999999997 A on CC Pod at time index 0.
#   warnings.warn(

# %% [markdown]
# ## [Analysis][acn-sim_1-analysis]
#
# Once the simulator has been run, we can analyze the results. For this purpose acnsim offers a package called analysis. One thing we may be interested in is the proportion of total users’ energy demand that we were able to meet. To find this we can use the proportion_of_energy_delivered() method from the analysis subpackage. The only argument to this function is the Simulator object itself.
#
# [acn-sim_1-analysis]: https://acnportal.readthedocs.io/en/latest/tutorials/acnsim/lesson1.html#Analysis

# %%
total_energy_prop = acnsim.proportion_of_energy_delivered(sim)
print('Proportion of requested energy delivered: {0}'.format(total_energy_prop))
# Out:
# Proportion of requested energy delivered: 0.9998668404675912

# %% [markdown]
# We may also be interested in the peak demand of the system as this determines our big the root transformers and cables in our system must be as well as the demand charge we may have to pay. The Simulator has a built in property which keeps track of this peak usage called peak.

# %%
print('Peak aggregate current: {0} A'.format(sim.peak))
# Out:
# Peak aggregate current: 704.0 A

# %% [markdown]
# Finally, we can plot the output of our simulation. For now we will just plot total aggregate current draw:

# %%
# Plotting aggregate current
agg_current = acnsim.aggregate_current(sim)
plt.plot(agg_current)
plt.xlabel('Time (periods)')
plt.ylabel('Current (A)')
plt.title('Total Aggregate Current')
plt.show()
